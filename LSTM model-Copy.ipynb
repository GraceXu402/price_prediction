# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression,LogisticRegression
from statsmodels.tools.sm_exceptions import ConvergenceWarning
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import label_binarize, LabelEncoder,MinMaxScaler,StandardScaler
from sklearn.feature_selection import mutual_info_classif
from scipy.stats import entropy
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
import xgboost as xgb

from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras.regularizers import l2
from keras.layers import BatchNormalization
from keras.optimizers import RMSprop
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras import Sequential
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import AUC, Precision, Recall



from collections import Counter
from sklearn.metrics import roc_curve, auc,accuracy_score
import pickle
from sklearn.decomposition import PCA

from datetime import datetime
from datetime import date


import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# ### Import Data

# %%
btc_hourly_return = pd.read_csv('btc_hourly_return_selected.csv')
btc_hourly_return.index =pd.to_datetime(btc_hourly_return['timestamp'])
btc_hourly_return.drop(columns=['timestamp'],inplace=True)
#btc_min_return=btc_min_return[btc_min_return.index > '2019']
btc_hourly_return['return_scaled'] = btc_hourly_return['return']*100

features_removed = ['return','return_scaled','J_test_statistic', 'jump_detected_3_3','jump_size_3_3','RV_d','log1+J','RS','scale_right','shape_right','scale_left','shape_left']
features = btc_hourly_return.columns.to_list()
features = [item for item in features if item not in features_removed]
TI_features = features[:6]+features[-17:]
SV_features = features[:-17]
Naive_features = features[:6]

# %%
btc_daily_return = pd.read_csv('btc_daily_return_selected.csv')
btc_daily_return.index =pd.to_datetime(btc_daily_return['timestamp'])
btc_daily_return.drop(columns=['timestamp'],inplace=True)
#btc_min_return=btc_min_return[btc_min_return.index > '2019']
btc_daily_return['return_scaled'] = btc_daily_return['return']*100

features_removed = ['return','return_scaled','J_test_statistic', 'jump_detected_3_3','jump_size_3_3','RV_d','log1+J','RS','scale_right','shape_right','scale_left','shape_left']
features = btc_daily_return.columns.to_list()
features = [item for item in features if item not in features_removed]
TI_features = features[:6]+features[-17:]
SV_features = features[:-17]
Naive_features = features[:6]

# %% [markdown]
# ### Generate labels

# %%
quantile_upper = 0.8
quantile_lower = 1-quantile_upper
accuracy_metric = 'Build_in_acc'
target_used = 'target_quantile'

# %%
# Create the target variable -- Quantile based threshold
df = btc_daily_return.copy()[features+['return_scaled','return']]

upper_quantile = df['return_scaled'].quantile(quantile_upper)
lower_quantile = df['return_scaled'].quantile(quantile_lower)
df['target_quantile'] = 0
df.loc[df['return_scaled'].shift(-1) > upper_quantile, 'target_quantile'] = 1
df.loc[df['return_scaled'].shift(-1) < lower_quantile, 'target_quantile'] = -1
df = df.dropna()
print([upper_quantile,lower_quantile])
# Out:
# [0.03919483220352, -0.051800631653960004]

# %%
X = df[features]
y = df[target_used]

# Split the data into training and test sets
cutoff_date = '2021-01-01'
X_train = X[df.index < cutoff_date]
scaler = StandardScaler()
X_train= scaler.fit_transform(X_train)
X_test = X[df.index >= cutoff_date]
scaler = StandardScaler()
X_test= scaler.fit_transform(X_test)
y_train = y[df.index < cutoff_date]
y_test = y[df.index >= cutoff_date]

X_TI = df[TI_features]
X_train_TI = X_TI[df[TI_features].index < cutoff_date]
scaler = StandardScaler()
X_train_TI= scaler.fit_transform(X_train_TI)
X_test_TI = X_TI[df[TI_features].index >= cutoff_date]
scaler = StandardScaler()
X_test_TI= scaler.fit_transform(X_test_TI)

X_SV = df[SV_features]
scaler = StandardScaler()
X_SV= scaler.fit_transform(X_SV)
X_train_SV = X_SV[df[SV_features].index < cutoff_date]
X_test_SV = X_SV[df[SV_features].index >= cutoff_date]

X_Naive = df[Naive_features]
scaler = StandardScaler()
X_Naive= scaler.fit_transform(X_Naive)
X_train_Naive = X_Naive[df[Naive_features].index < cutoff_date]
X_test_Naive = X_Naive[df[Naive_features].index >= cutoff_date]

# %% [markdown]
# ### Define Accuracy metrics
#
# - Type I error: FP (reject null while null is true)
#
# - Type II error: FN (not reject null while null is not true)
#
# - Precision: $\frac{TP}{TP + FP}$
#
# - Recall: $\frac{TP}{TP + FN}$
#
# - F1-Score: $2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}$
#
# - Accuracy_function:
#
# $\text{Profit}-\text{accuracy} = \frac{TD + TI}{TD + TI + FDN+FIN+FID+FDI}$;
#
# s.t.
# TD: the number of true predictions decreases; FDN: the number of predictions of the no-action class decreases; FDI: the number of predictions of the increase class decreases and etc.

# %%
def custom_accuracy(y_true, y_pred):
    Accuracy = {}
    
    # Acc_True: Standard accuracy
    Accuracy['Accuracy'] = accuracy_score(y_true, y_pred)
    
    # Round the accuracy values to 2 decimal places
    Acc = {k: round(v, 2) for k, v in Accuracy.items()}
    
    # Return the accuracies as a DataFrame
    return pd.DataFrame([Acc])

# %% [markdown]
# ### LSTM

# %%
def custom_f1_score(y_true, y_pred):
    # Ensure y_true and y_pred are of integer type
    y_true = K.cast(y_true, 'int32')
    y_pred = K.argmax(y_pred, axis=-1)
    
    # Convert to one-hot encoding for F1 score calculation
    num_classes = tf.reduce_max(y_true) + 1
    y_true_one_hot = tf.one_hot(y_true, depth=num_classes)
    y_pred_one_hot = tf.one_hot(y_pred, depth=num_classes)
    
    # Calculate True Positives, False Positives, False Negatives
    tp = K.sum(K.cast(y_true_one_hot * y_pred_one_hot, 'float32'), axis=0)
    fp = K.sum(K.cast((1 - y_true_one_hot) * y_pred_one_hot, 'float32'), axis=0)
    fn = K.sum(K.cast(y_true_one_hot * (1 - y_pred_one_hot), 'float32'), axis=0)
    
    # Calculate Precision, Recall
    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())
    
    # Calculate F1 score for each class
    f1 = 2 * (precision * recall) / (precision + recall + K.epsilon())
    
    # Return the average F1 score across all classes
    return K.mean(f1)

def custom_precision(y_true, y_pred):
    y_true = K.cast(y_true, 'int32')
    y_pred = K.argmax(y_pred, axis=-1)
    num_classes = tf.reduce_max(y_true) + 1
    y_true_one_hot = tf.one_hot(y_true, depth=num_classes)
    y_pred_one_hot = tf.one_hot(y_pred, depth=num_classes)
    tp = K.sum(K.cast(y_true_one_hot * y_pred_one_hot, 'float32'), axis=0)
    fp = K.sum(K.cast((1 - y_true_one_hot) * y_pred_one_hot, 'float32'), axis=0)
    precision = tp / (tp + fp + K.epsilon())
    return K.mean(precision)

def custom_recall(y_true, y_pred):
    # Ensure y_true and y_pred are of integer type
    y_true = K.cast(y_true, 'int32')
    y_pred = K.argmax(y_pred, axis=-1)
    
    # Convert to one-hot encoding for recall calculation
    num_classes = tf.reduce_max(y_true) + 1
    y_true_one_hot = tf.one_hot(y_true, depth=num_classes)
    y_pred_one_hot = tf.one_hot(y_pred, depth=num_classes)
    
    # Calculate True Positives and False Negatives
    tp = K.sum(K.cast(y_true_one_hot * y_pred_one_hot, 'float32'), axis=0)
    fn = K.sum(K.cast(y_true_one_hot * (1 - y_pred_one_hot), 'float32'), axis=0)
    
    # Calculate Recall for each class
    recall = tp / (tp + fn + K.epsilon())
    
    # Return the average Recall across all classes
    return K.mean(recall)

def custom_auc(y_true, y_pred):
    # Ensure y_true and y_pred are of integer type
    y_true = K.cast(y_true, 'int32')
    y_pred = tf.nn.softmax(y_pred)  # Convert logits to probabilities
    
    # Define AUC metric
    auc_metric = tf.keras.metrics.AUC()
    
    # Update the metric with the true labels and predictions
    auc_metric.update_state(y_true, y_pred)
    
    # Return the result of AUC
    return auc_metric.result()


def plot_metrics(history, metric='accuracy'):
 
    plt.figure(figsize=(6, 3))  # Adjust the figure size

    # Plot training and validation loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    # Plot training and validation accuracy (or other metric)
    plt.subplot(1, 2, 2)
    if metric == 'accuracy':
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title('Accuracy')
    else:
        plt.plot(history.history[metric], label=f'Training {metric.capitalize()}')
        plt.plot(history.history[f'val_{metric}'], label=f'Validation {metric.capitalize()}')
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.legend()

    plt.tight_layout()
    plt.show()

def build_lstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=regularizers.l2(0.01))))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Bidirectional(LSTM(64, return_sequences=True, kernel_regularizer=regularizers.l2(0.01))))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(LSTM(32, return_sequences=False, kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    return model


def build_and_train_lstm(X_train, y_train, X_test, y_test, 
                         epochs=50, patience=6, learning_rate=0.005, 
                         metric=custom_f1_score, 
                         plot_metrics_flag=False):
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Encoding the labels
    label_encoder = LabelEncoder()
    y_train_encoded = label_encoder.fit_transform(y_train)
    y_test_encoded = label_encoder.transform(y_test)

    # Reshaping the input data for LSTM
    X_train_lstm = np.reshape(X_train_scaled, (X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
    X_test_lstm = np.reshape(X_test_scaled, (X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

    # Calculating class weights to handle imbalanced data
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train_encoded), y=y_train_encoded)
    class_weight_dict = dict(enumerate(class_weights))

    # Building the LSTM model
    model = build_lstm_model(input_shape=(1, X_train_scaled.shape[1]), num_classes=len(label_encoder.classes_))

    # Compiling the model with the specified optimizer and loss function
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, 
                  loss='sparse_categorical_crossentropy', 
                  metrics=[metric,'accuracy'])
    
    # Setting up early stopping to prevent overfitting
    early_stopping_callback = EarlyStopping(
        monitor='val_loss',
        patience=patience,
        restore_best_weights=True
    )

    # Training the model
    history = model.fit(X_train_lstm, y_train_encoded,
                        epochs=epochs,
                        batch_size=64,
                        verbose=2,
                        validation_data=(X_test_lstm, y_test_encoded),
                        callbacks=[early_stopping_callback],
                        class_weight=class_weight_dict)

    # Plotting the metrics if the flag is set
    if plot_metrics_flag:
        plot_metrics(history, metric='accuracy')  # This will plot both loss and accuracy curves

    # Making predictions on the test set
    y_pred_prob = model.predict(X_test_lstm)
    y_pred_encoded = np.argmax(y_pred_prob, axis=1)
    y_pred_class = label_encoder.inverse_transform(y_pred_encoded)

    return y_pred_prob, y_pred_class


def evaluate_lstm_model(X_train, y_train, X_test, y_test, 
                        epochs_list, metric_list, learning_rate_list):
    results = {}

    # Iterate through each combination of epochs, metrics, and learning rates
    for metric in metric_list:
        for learning_rate in learning_rate_list:
            for epochs in epochs_list:
                print(f'\nTraining with {epochs} epochs, learning rate {learning_rate}, and metrics {metric.__name__}...\n')

                # Train the LSTM model with the specified parameters
                y_pred_prob, y_pred_class = build_and_train_lstm(
                    X_train, y_train, X_test, y_test,
                    epochs=epochs,
                    learning_rate=learning_rate,
                    metric=metric
                )

                # Manually calculate custom accuracy (assuming the function takes y_true and y_pred as np arrays)
                custom_acc = custom_accuracy(y_test, y_pred_class)
                print(f'Custom accuracy: {custom_acc}')
                
                # Store results
                results[(metric.__name__, learning_rate, epochs)] = {
                    'custom_acc': custom_acc,
                    'y_pred_prob': y_pred_prob,
                    'y_pred_class': y_pred_class,
                    'custom_accuracies_df': custom_acc
                }

    return results

# %%
def create_hybrid_predictions(y_pred_class_SV, y_pred_prob_SV, y_pred_class_TI, y_pred_prob_TI):
    final_predictions = []
    final_probabilities = []

    for pred_SV, prob_SV, pred_TI, prob_TI in zip(y_pred_class_SV, y_pred_prob_SV, y_pred_class_TI, y_pred_prob_TI):
        if pred_SV == 0 or pred_TI == 0:
            # If either model predicts class-noact (0), the final decision is class-noact (0)
            final_predictions.append(0)
            final_probabilities.append(prob_SV)  # No active probabilities
        elif pred_SV == pred_TI:
            # If both models agree on the label, use that label
            final_predictions.append(pred_SV)
            final_probabilities.append(prob_SV)  
        else:
            # If predictions are different, compare the probabilities for the predicted classes
            prob_SV_pred = prob_SV[np.argmax(prob_SV)]  # Probability for the class predicted by SV
            prob_TI_pred = prob_TI[np.argmax(prob_TI)]  # Probability for the class predicted by TI
            
            if prob_SV_pred > prob_TI_pred:
                final_predictions.append(pred_SV)
                final_probabilities.append(prob_SV)
            elif prob_SV_pred < prob_TI_pred:
                final_predictions.append(pred_TI)
                final_probabilities.append(prob_TI)
            else:
                # If probabilities are the same, choose the SV model's prediction
                final_predictions.append(pred_SV)
                final_probabilities.append(prob_SV)
    
    return np.array(final_predictions), np.array(final_probabilities)

def generate_hybrid_predictions(metric_list,learn_rate_list, epochs_list, results_SV, results_TI, create_hybrid_predictions):
    # Initialize a dictionary to store hybrid results
    results_Hybrid = {}

    # Iterate through each epoch to generate hybrid predictions
    for metric in metric_list:
        for learning_rate in learn_rate_list:
            for epochs in epochs_list:
                y_pred_class_SV = results_SV[(metric.__name__, learning_rate, epochs)]['y_pred_class']
                y_pred_prob_SV = results_SV[(metric.__name__, learning_rate, epochs)]['y_pred_prob']
                y_pred_class_TI = results_TI[(metric.__name__, learning_rate, epochs)]['y_pred_class']
                y_pred_prob_TI = results_TI[(metric.__name__, learning_rate, epochs)]['y_pred_prob']

        # Generate hybrid predictions and probabilities
        hybrid_pred_class, hybrid_pred_prob = create_hybrid_predictions(
            y_pred_class_SV, y_pred_prob_SV, y_pred_class_TI, y_pred_prob_TI
        )

        # Store hybrid results for this epoch
        results_Hybrid[(metric.__name__, learning_rate, epochs)] = {
            'y_pred_class': hybrid_pred_class,
            'y_pred_prob': hybrid_pred_prob
        }
    
    return results_Hybrid



def create_trade_summary(y_true, results, metric_list,learn_rate_list, epochs_list, models):
    summary_data = []

    for metric in metric_list:
        for learning_rate in learn_rate_list:
            for epochs in epochs_list:
                row_data = {('metric', 'learning_rate', 'epochs'): (metric.__name__, learning_rate, epochs)}

                for model in models:
                    y_pred_class = results[model][(metric.__name__, learning_rate, epochs)]['y_pred_class']
                    acc = np.round(accuracy_score(y_true, y_pred_class),2)

                    count = Counter(y_pred_class)
                    pos_trade_count = count.get(1, 0)  # Positive trades count
                    neg_trade_count = count.get(-1, 0)  # Negative trades count (if -1 is in the labels)
                    no_action_count = count.get(0, 0)  # No-action count (if 0 is in the labels)
                    total_transac = pos_trade_count + neg_trade_count 
                    total_transac_ptc = total_transac / (total_transac + no_action_count) 
                    pos_trade_ptc = f"{(pos_trade_count / total_transac * 100):.0f}%" if total_transac > 0 else "0.00%"
                    neg_trade_ptc = f"{(neg_trade_count / total_transac * 100):.0f}%" if total_transac > 0 else "0.00%"
                    total_transac_ptc = f"{(total_transac_ptc * 100):.0f}%" if total_transac > 0 else "0.00%"
                    row_data[(model, 'Accuracy')] = acc
                    row_data[(model, 'Pos_trade_pct')] = pos_trade_ptc
                    row_data[(model, 'Neg_trade_pct')] = neg_trade_ptc
                    #row_data[(model, 'Total_transac')] = total_transac
                    row_data[(model, 'Total_transac_pct')] = total_transac_ptc
        
                summary_data.append(row_data)

    summary_df = pd.DataFrame(summary_data)
    summary_df.set_index(('metric', 'learning_rate', 'epochs'), inplace=True)
    summary_df.columns = pd.MultiIndex.from_tuples(summary_df.columns)
    
    return summary_df

# %% [markdown]
# #### Model Comparison

# %%
# Define the epochs list
epochs_list = [30]
learn_rate_list = [0.001]
metric_list = [custom_f1_score, custom_precision, custom_recall]


results_Naive = evaluate_lstm_model(X_train_Naive, y_train, X_test_Naive, y_test, epochs_list=epochs_list,metric_list=metric_list,learning_rate_list=learn_rate_list)
results_SV = evaluate_lstm_model(X_train_SV, y_train, X_test_SV, y_test, epochs_list=epochs_list,metric_list=metric_list,learning_rate_list=learn_rate_list)
results_TI = evaluate_lstm_model(X_train_TI, y_train, X_test_TI, y_test, epochs_list=epochs_list,metric_list=metric_list,learning_rate_list=learn_rate_list)
results_Full = evaluate_lstm_model(X_train, y_train, X_test, y_test, epochs_list=epochs_list,metric_list=metric_list,learning_rate_list=learn_rate_list)
# Out:
# Training with 30 epochs, learning rate 0.001, and metrics custom_f1_score...
#
# Epoch 1/30
# 11/11 - 9s - 823ms/step - accuracy: 0.3462 - custom_f1_score: 0.3112 - loss: 8.7536 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 7.7665
# Epoch 2/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3536 - custom_f1_score: 0.3239 - loss: 7.9557 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 7.1307
# Epoch 3/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3730 - custom_f1_score: 0.3390 - loss: 7.3226 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 6.5821
# Epoch 4/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3863 - custom_f1_score: 0.3614 - loss: 6.6361 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 6.1209
# Epoch 5/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3373 - custom_f1_score: 0.3174 - loss: 6.2515 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 5.7217
# Epoch 6/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3774 - custom_f1_score: 0.3445 - loss: 5.7596 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 5.3928
# Epoch 7/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3239 - custom_f1_score: 0.3046 - loss: 5.5771 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 5.1081
# Epoch 8/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3670 - custom_f1_score: 0.3334 - loss: 5.2503 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 4.8700
# Epoch 9/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3804 - custom_f1_score: 0.3518 - loss: 4.9463 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 4.6526
# Epoch 10/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3551 - custom_f1_score: 0.3209 - loss: 4.7104 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 4.4657
# Epoch 11/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3596 - custom_f1_score: 0.3163 - loss: 4.6221 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 4.3035
# Epoch 12/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3774 - custom_f1_score: 0.3474 - loss: 4.4058 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 4.1595
# Epoch 13/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3655 - custom_f1_score: 0.3280 - loss: 4.2546 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 4.0357
# Epoch 14/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3507 - custom_f1_score: 0.3188 - loss: 4.0971 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.9183
# Epoch 15/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3744 - custom_f1_score: 0.3436 - loss: 3.9840 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.8170
# Epoch 16/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3938 - custom_f1_score: 0.3641 - loss: 3.8460 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.7164
# Epoch 17/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3655 - custom_f1_score: 0.3311 - loss: 3.7604 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.6316
# Epoch 18/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3536 - custom_f1_score: 0.3098 - loss: 3.6950 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.5461
# Epoch 19/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3715 - custom_f1_score: 0.3465 - loss: 3.5886 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.4645
# Epoch 20/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3863 - custom_f1_score: 0.3657 - loss: 3.4511 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.3718
# Epoch 21/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3893 - custom_f1_score: 0.3683 - loss: 3.3487 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.2953
# Epoch 22/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3804 - custom_f1_score: 0.3486 - loss: 3.2963 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.2102
# Epoch 23/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3878 - custom_f1_score: 0.3600 - loss: 3.1971 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.1309
# Epoch 24/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3507 - custom_f1_score: 0.3214 - loss: 3.1806 - val_accuracy: 0.2344 - val_custom_f1_score: 0.1464 - val_loss: 3.0514
# Epoch 25/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3640 - custom_f1_score: 0.3326 - loss: 3.0937 - val_accuracy: 0.2683 - val_custom_f1_score: 0.1679 - val_loss: 2.9860
# Epoch 26/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3596 - custom_f1_score: 0.3230 - loss: 3.0485 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 2.9539
# Epoch 27/30
# 11/11 - 0s - 19ms/step - accuracy: 0.3596 - custom_f1_score: 0.3251 - loss: 2.9987 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 2.8919
# Epoch 28/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3640 - custom_f1_score: 0.3268 - loss: 2.9083 - val_accuracy: 0.3107 - val_custom_f1_score: 0.1621 - val_loss: 2.8063
# Epoch 29/30
# 11/11 - 0s - 20ms/step - accuracy: 0.3700 - custom_f1_score: 0.3222 - loss: 2.8770 - val_accuracy: 0.3086 - val_custom_f1_score: 0.1655 - val_loss: 2.7510
# Epoch 30/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3507 - custom_f1_score: 0.3178 - loss: 2.8409 - val_accuracy: 0.3097 - val_custom_f1_score: 0.1614 - val_loss: 2.6993
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# Custom accuracy:    Accuracy
# 0      0.31
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_precision...
#
# Epoch 1/30
# 11/11 - 10s - 914ms/step - accuracy: 0.3120 - custom_precision: 0.3314 - loss: 8.9297 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 7.8301
# Epoch 2/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3239 - custom_precision: 0.3307 - loss: 8.0482 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 7.2285
# Epoch 3/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3224 - custom_precision: 0.3191 - loss: 7.4216 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 6.7161
# Epoch 4/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3522 - custom_precision: 0.3553 - loss: 6.8568 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 6.2871
# Epoch 5/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3670 - custom_precision: 0.3563 - loss: 6.4061 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 5.9303
# Epoch 6/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3403 - custom_precision: 0.3267 - loss: 6.1301 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 5.6315
# Epoch 7/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3180 - custom_precision: 0.3140 - loss: 5.7176 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 5.3829
# Epoch 8/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3239 - custom_precision: 0.3213 - loss: 5.5056 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 5.1622
# Epoch 9/30
# 11/11 - 0s - 28ms/step - accuracy: 0.3655 - custom_precision: 0.3744 - loss: 5.2424 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.9502
# Epoch 10/30
# 11/11 - 0s - 23ms/step - accuracy: 0.3492 - custom_precision: 0.3571 - loss: 4.9983 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.7770
# Epoch 11/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3418 - custom_precision: 0.3255 - loss: 4.8573 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.6221
# Epoch 12/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3611 - custom_precision: 0.3563 - loss: 4.6366 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.4847
# Epoch 13/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3819 - custom_precision: 0.3749 - loss: 4.4233 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.3620
# Epoch 14/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3299 - custom_precision: 0.3250 - loss: 4.3573 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.2404
# Epoch 15/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3759 - custom_precision: 0.3623 - loss: 4.1877 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.1465
# Epoch 16/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3566 - custom_precision: 0.3530 - loss: 4.0625 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.0474
# Epoch 17/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3522 - custom_precision: 0.3537 - loss: 4.0112 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.9532
# Epoch 18/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3522 - custom_precision: 0.3489 - loss: 3.9052 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.8688
# Epoch 19/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3328 - custom_precision: 0.3399 - loss: 3.7825 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.7783
# Epoch 20/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3834 - custom_precision: 0.3791 - loss: 3.6724 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.7000
# Epoch 21/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3299 - custom_precision: 0.3301 - loss: 3.6134 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.6135
# Epoch 22/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3403 - custom_precision: 0.3461 - loss: 3.4980 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.5201
# Epoch 23/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3477 - custom_precision: 0.3678 - loss: 3.4171 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.4445
# Epoch 24/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3447 - custom_precision: 0.3465 - loss: 3.3616 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.3515
# Epoch 25/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3239 - custom_precision: 0.3318 - loss: 3.2936 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.2826
# Epoch 26/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3343 - custom_precision: 0.3288 - loss: 3.2648 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.2025
# Epoch 27/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3462 - custom_precision: 0.3556 - loss: 3.1645 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.1395
# Epoch 28/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3195 - custom_precision: 0.3295 - loss: 3.0970 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.0982
# Epoch 29/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3462 - custom_precision: 0.3591 - loss: 3.0680 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.0294
# Epoch 30/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3700 - custom_precision: 0.3647 - loss: 2.9583 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 2.9611
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Custom accuracy:    Accuracy
# 0      0.19
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_recall...
#
# Epoch 1/30
# 11/11 - 9s - 827ms/step - accuracy: 0.3001 - custom_recall: 0.3221 - loss: 8.9293 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 7.8760
# Epoch 2/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3447 - custom_recall: 0.3775 - loss: 8.0558 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 7.2257
# Epoch 3/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3076 - custom_recall: 0.3219 - loss: 7.3538 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 6.6753
# Epoch 4/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3373 - custom_recall: 0.3652 - loss: 6.8372 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 6.2152
# Epoch 5/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3566 - custom_recall: 0.3876 - loss: 6.2567 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 5.8381
# Epoch 6/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3165 - custom_recall: 0.3409 - loss: 6.0027 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 5.5198
# Epoch 7/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3611 - custom_recall: 0.3759 - loss: 5.6591 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 5.2410
# Epoch 8/30
# 11/11 - 0s - 12ms/step - accuracy: 0.2912 - custom_recall: 0.2949 - loss: 5.3836 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 5.0063
# Epoch 9/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3626 - custom_recall: 0.3737 - loss: 5.0999 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 4.8069
# Epoch 10/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3477 - custom_recall: 0.3555 - loss: 4.9214 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 4.6423
# Epoch 11/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3299 - custom_recall: 0.3513 - loss: 4.7201 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 4.4841
# Epoch 12/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3269 - custom_recall: 0.3285 - loss: 4.5935 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 4.3452
# Epoch 13/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3299 - custom_recall: 0.3503 - loss: 4.4218 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 4.2200
# Epoch 14/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3120 - custom_recall: 0.3136 - loss: 4.3133 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 4.0991
# Epoch 15/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3566 - custom_recall: 0.3727 - loss: 4.1366 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.9772
# Epoch 16/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3848 - custom_recall: 0.3997 - loss: 4.0159 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.8560
# Epoch 17/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3388 - custom_recall: 0.3580 - loss: 3.9108 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.7517
# Epoch 18/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3596 - custom_recall: 0.3783 - loss: 3.7868 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.6542
# Epoch 19/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3284 - custom_recall: 0.3452 - loss: 3.7153 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.5702
# Epoch 20/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3670 - custom_recall: 0.3823 - loss: 3.5964 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.4864
# Epoch 21/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3507 - custom_recall: 0.3460 - loss: 3.5264 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.4016
# Epoch 22/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3254 - custom_recall: 0.3389 - loss: 3.4684 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.3213
# Epoch 23/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3091 - custom_recall: 0.3088 - loss: 3.3793 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.2524
# Epoch 24/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3224 - custom_recall: 0.3278 - loss: 3.3207 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.1875
# Epoch 25/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3328 - custom_recall: 0.3271 - loss: 3.2138 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.1276
# Epoch 26/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3670 - custom_recall: 0.3833 - loss: 3.1292 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.0749
# Epoch 27/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3299 - custom_recall: 0.3483 - loss: 3.0940 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.0203
# Epoch 28/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3655 - custom_recall: 0.3777 - loss: 3.0261 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 2.9608
# Epoch 29/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3492 - custom_recall: 0.3555 - loss: 2.9820 - val_accuracy: 0.2195 - val_custom_recall: 0.3379 - val_loss: 2.8918
# Epoch 30/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3091 - custom_recall: 0.3316 - loss: 2.9567 - val_accuracy: 0.2407 - val_custom_recall: 0.3293 - val_loss: 2.8333
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Custom accuracy:    Accuracy
# 0      0.24
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_f1_score...
#
# Epoch 1/30
# 11/11 - 9s - 838ms/step - accuracy: 0.3418 - custom_f1_score: 0.3191 - loss: 9.2296 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 8.3663
# Epoch 2/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3536 - custom_f1_score: 0.3293 - loss: 8.4336 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 7.7185
# Epoch 3/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3685 - custom_f1_score: 0.3384 - loss: 7.8044 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 7.1867
# Epoch 4/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3403 - custom_f1_score: 0.3213 - loss: 7.2372 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 6.7412
# Epoch 5/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3700 - custom_f1_score: 0.3492 - loss: 6.7373 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 6.3576
# Epoch 6/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3596 - custom_f1_score: 0.3416 - loss: 6.3889 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 6.0204
# Epoch 7/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3670 - custom_f1_score: 0.3419 - loss: 6.0682 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 5.7179
# Epoch 8/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3774 - custom_f1_score: 0.3563 - loss: 5.7256 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 5.4579
# Epoch 9/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3744 - custom_f1_score: 0.3524 - loss: 5.4786 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 5.2361
# Epoch 10/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3314 - custom_f1_score: 0.3185 - loss: 5.3066 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 5.0202
# Epoch 11/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3328 - custom_f1_score: 0.3098 - loss: 5.1130 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 4.8261
# Epoch 12/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3982 - custom_f1_score: 0.3729 - loss: 4.8511 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 4.6498
# Epoch 13/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3700 - custom_f1_score: 0.3509 - loss: 4.6728 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 4.4875
# Epoch 14/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3626 - custom_f1_score: 0.3425 - loss: 4.5439 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 4.3465
# Epoch 15/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3626 - custom_f1_score: 0.3487 - loss: 4.3656 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 4.2138
# Epoch 16/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3462 - custom_f1_score: 0.3291 - loss: 4.2396 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 4.0902
# Epoch 17/30
# 11/11 - 0s - 19ms/step - accuracy: 0.3923 - custom_f1_score: 0.3763 - loss: 4.0754 - val_accuracy: 0.1803 - val_custom_f1_score: 0.0962 - val_loss: 3.9774
# Epoch 18/30
# 11/11 - 0s - 27ms/step - accuracy: 0.3655 - custom_f1_score: 0.3492 - loss: 3.9707 - val_accuracy: 0.1760 - val_custom_f1_score: 0.1087 - val_loss: 3.8672
# Epoch 19/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4012 - custom_f1_score: 0.3819 - loss: 3.8456 - val_accuracy: 0.1856 - val_custom_f1_score: 0.1058 - val_loss: 3.7643
# Epoch 20/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3655 - custom_f1_score: 0.3382 - loss: 3.7532 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.6652
# Epoch 21/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3789 - custom_f1_score: 0.3652 - loss: 3.6305 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.5731
# Epoch 22/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3581 - custom_f1_score: 0.3471 - loss: 3.5257 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.4784
# Epoch 23/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3551 - custom_f1_score: 0.3422 - loss: 3.4993 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.3904
# Epoch 24/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3640 - custom_f1_score: 0.3382 - loss: 3.3806 - val_accuracy: 0.1909 - val_custom_f1_score: 0.1012 - val_loss: 3.3090
# Epoch 25/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3848 - custom_f1_score: 0.3706 - loss: 3.3095 - val_accuracy: 0.1888 - val_custom_f1_score: 0.1021 - val_loss: 3.2321
# Epoch 26/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3744 - custom_f1_score: 0.3553 - loss: 3.2165 - val_accuracy: 0.1877 - val_custom_f1_score: 0.1031 - val_loss: 3.1571
# Epoch 27/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3655 - custom_f1_score: 0.3434 - loss: 3.1696 - val_accuracy: 0.1866 - val_custom_f1_score: 0.1108 - val_loss: 3.0957
# Epoch 28/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3640 - custom_f1_score: 0.3564 - loss: 3.0583 - val_accuracy: 0.1888 - val_custom_f1_score: 0.1156 - val_loss: 3.0400
# Epoch 29/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3923 - custom_f1_score: 0.3704 - loss: 2.9940 - val_accuracy: 0.1845 - val_custom_f1_score: 0.1128 - val_loss: 2.9869
# Epoch 30/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3804 - custom_f1_score: 0.3610 - loss: 2.9613 - val_accuracy: 0.1845 - val_custom_f1_score: 0.1119 - val_loss: 2.9335
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# Custom accuracy:    Accuracy
# 0      0.18
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_precision...
#
# Epoch 1/30
# 11/11 - 10s - 930ms/step - accuracy: 0.3224 - custom_precision: 0.3244 - loss: 9.2992 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 8.3366
# Epoch 2/30
# 11/11 - 1s - 122ms/step - accuracy: 0.3655 - custom_precision: 0.3709 - loss: 8.4555 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 7.6923
# Epoch 3/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3120 - custom_precision: 0.3267 - loss: 7.8790 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 7.1559
# Epoch 4/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3373 - custom_precision: 0.3429 - loss: 7.3760 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.7087
# Epoch 5/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3611 - custom_precision: 0.3672 - loss: 6.8826 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.3333
# Epoch 6/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3759 - custom_precision: 0.3639 - loss: 6.4763 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.0105
# Epoch 7/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3239 - custom_precision: 0.3360 - loss: 6.2597 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.7340
# Epoch 8/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3626 - custom_precision: 0.3715 - loss: 5.9172 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.4843
# Epoch 9/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3403 - custom_precision: 0.3430 - loss: 5.6776 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.2645
# Epoch 10/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3061 - custom_precision: 0.3006 - loss: 5.5374 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.0647
# Epoch 11/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3551 - custom_precision: 0.3525 - loss: 5.2597 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.8875
# Epoch 12/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3403 - custom_precision: 0.3607 - loss: 5.0787 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.7247
# Epoch 13/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3120 - custom_precision: 0.3224 - loss: 4.9406 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.5772
# Epoch 14/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3432 - custom_precision: 0.3440 - loss: 4.7074 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.4322
# Epoch 15/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3640 - custom_precision: 0.3785 - loss: 4.5064 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.2953
# Epoch 16/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3507 - custom_precision: 0.3564 - loss: 4.4480 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.1703
# Epoch 17/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3596 - custom_precision: 0.3610 - loss: 4.2885 - val_accuracy: 0.6278 - val_custom_precision: 0.2174 - val_loss: 4.0581
# Epoch 18/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3626 - custom_precision: 0.3714 - loss: 4.1477 - val_accuracy: 0.6278 - val_custom_precision: 0.2263 - val_loss: 3.9523
# Epoch 19/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3670 - custom_precision: 0.3705 - loss: 4.0390 - val_accuracy: 0.5493 - val_custom_precision: 0.2576 - val_loss: 3.8526
# Epoch 20/30
# 11/11 - 0s - 19ms/step - accuracy: 0.3655 - custom_precision: 0.3621 - loss: 3.9486 - val_accuracy: 0.2609 - val_custom_precision: 0.1617 - val_loss: 3.7584
# Epoch 21/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3507 - custom_precision: 0.3611 - loss: 3.8580 - val_accuracy: 0.2068 - val_custom_precision: 0.1029 - val_loss: 3.6689
# Epoch 22/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3492 - custom_precision: 0.3557 - loss: 3.7358 - val_accuracy: 0.1824 - val_custom_precision: 0.0870 - val_loss: 3.5847
# Epoch 23/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3700 - custom_precision: 0.3705 - loss: 3.6374 - val_accuracy: 0.1824 - val_custom_precision: 0.0877 - val_loss: 3.5015
# Epoch 24/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3774 - custom_precision: 0.3861 - loss: 3.4935 - val_accuracy: 0.1813 - val_custom_precision: 0.0663 - val_loss: 3.4293
# Epoch 25/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3314 - custom_precision: 0.3340 - loss: 3.4941 - val_accuracy: 0.1877 - val_custom_precision: 0.1173 - val_loss: 3.3630
# Epoch 26/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3566 - custom_precision: 0.3642 - loss: 3.3903 - val_accuracy: 0.1813 - val_custom_precision: 0.0663 - val_loss: 3.2947
# Epoch 27/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3952 - custom_precision: 0.3923 - loss: 3.2994 - val_accuracy: 0.1813 - val_custom_precision: 0.0935 - val_loss: 3.2246
# Epoch 28/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3982 - custom_precision: 0.4079 - loss: 3.2138 - val_accuracy: 0.1803 - val_custom_precision: 0.0890 - val_loss: 3.1614
# Epoch 29/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3789 - custom_precision: 0.3690 - loss: 3.1550 - val_accuracy: 0.1856 - val_custom_precision: 0.1063 - val_loss: 3.0993
# Epoch 30/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3655 - custom_precision: 0.3626 - loss: 3.0994 - val_accuracy: 0.1909 - val_custom_precision: 0.1163 - val_loss: 3.0463
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Custom accuracy:    Accuracy
# 0      0.19
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_recall...
#
# Epoch 1/30
# 11/11 - 9s - 863ms/step - accuracy: 0.3195 - custom_recall: 0.3363 - loss: 9.4879 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 8.3913
# Epoch 2/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3418 - custom_recall: 0.3282 - loss: 8.6267 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 7.7488
# Epoch 3/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3581 - custom_recall: 0.3569 - loss: 8.0237 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 7.2016
# Epoch 4/30
# 11/11 - 0s - 13ms/step - accuracy: 0.4205 - custom_recall: 0.4195 - loss: 7.3028 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 6.7471
# Epoch 5/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3685 - custom_recall: 0.3606 - loss: 7.0786 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 6.3565
# Epoch 6/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3640 - custom_recall: 0.3476 - loss: 6.6357 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 6.0357
# Epoch 7/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3685 - custom_recall: 0.3619 - loss: 6.3169 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 5.7567
# Epoch 8/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3730 - custom_recall: 0.3736 - loss: 5.9677 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 5.5130
# Epoch 9/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3477 - custom_recall: 0.3748 - loss: 5.7046 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 5.2984
# Epoch 10/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3774 - custom_recall: 0.3546 - loss: 5.5373 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 5.1014
# Epoch 11/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3566 - custom_recall: 0.3469 - loss: 5.3045 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 4.9162
# Epoch 12/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3447 - custom_recall: 0.3342 - loss: 5.1292 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 4.7457
# Epoch 13/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3759 - custom_recall: 0.3784 - loss: 4.9127 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 4.5901
# Epoch 14/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3759 - custom_recall: 0.3561 - loss: 4.8468 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 4.4446
# Epoch 15/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3715 - custom_recall: 0.3642 - loss: 4.6053 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 4.3126
# Epoch 16/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3655 - custom_recall: 0.3706 - loss: 4.5106 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 4.1931
# Epoch 17/30
# 11/11 - 0s - 19ms/step - accuracy: 0.3938 - custom_recall: 0.3968 - loss: 4.3486 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 4.0804
# Epoch 18/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3685 - custom_recall: 0.3623 - loss: 4.2442 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 3.9744
# Epoch 19/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3685 - custom_recall: 0.3705 - loss: 4.1300 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 3.8711
# Epoch 20/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3700 - custom_recall: 0.3676 - loss: 4.0024 - val_accuracy: 0.6076 - val_custom_recall: 0.3340 - val_loss: 3.7797
# Epoch 21/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4116 - custom_recall: 0.4181 - loss: 3.8289 - val_accuracy: 0.4252 - val_custom_recall: 0.3631 - val_loss: 3.6911
# Epoch 22/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3967 - custom_recall: 0.3977 - loss: 3.7704 - val_accuracy: 0.3245 - val_custom_recall: 0.3415 - val_loss: 3.6045
# Epoch 23/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3670 - custom_recall: 0.3623 - loss: 3.7027 - val_accuracy: 0.3075 - val_custom_recall: 0.3381 - val_loss: 3.5206
# Epoch 24/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3551 - custom_recall: 0.3524 - loss: 3.6228 - val_accuracy: 0.1962 - val_custom_recall: 0.3313 - val_loss: 3.4498
# Epoch 25/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3952 - custom_recall: 0.3881 - loss: 3.5118 - val_accuracy: 0.1898 - val_custom_recall: 0.3254 - val_loss: 3.3792
# Epoch 26/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3744 - custom_recall: 0.3827 - loss: 3.4275 - val_accuracy: 0.2015 - val_custom_recall: 0.3213 - val_loss: 3.3046
# Epoch 27/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3685 - custom_recall: 0.3715 - loss: 3.3484 - val_accuracy: 0.1994 - val_custom_recall: 0.3264 - val_loss: 3.2393
# Epoch 28/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3789 - custom_recall: 0.3799 - loss: 3.3107 - val_accuracy: 0.2121 - val_custom_recall: 0.3329 - val_loss: 3.1745
# Epoch 29/30
# 11/11 - 0s - 31ms/step - accuracy: 0.3774 - custom_recall: 0.3706 - loss: 3.2476 - val_accuracy: 0.2131 - val_custom_recall: 0.3338 - val_loss: 3.1095
# Epoch 30/30
# 11/11 - 0s - 18ms/step - accuracy: 0.4042 - custom_recall: 0.3970 - loss: 3.1320 - val_accuracy: 0.2121 - val_custom_recall: 0.3389 - val_loss: 3.0544
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# Custom accuracy:    Accuracy
# 0      0.21
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_f1_score...
#
# Epoch 1/30
# 11/11 - 10s - 879ms/step - accuracy: 0.3834 - custom_f1_score: 0.3592 - loss: 9.3343 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 8.4786
# Epoch 2/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3834 - custom_f1_score: 0.3607 - loss: 8.6570 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 7.8636
# Epoch 3/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3730 - custom_f1_score: 0.3407 - loss: 8.1036 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 7.3487
# Epoch 4/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3923 - custom_f1_score: 0.3606 - loss: 7.5277 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 6.9134
# Epoch 5/30
# 11/11 - 0s - 13ms/step - accuracy: 0.4101 - custom_f1_score: 0.3887 - loss: 7.0503 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 6.5369
# Epoch 6/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3507 - custom_f1_score: 0.3271 - loss: 6.7273 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 6.2090
# Epoch 7/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3848 - custom_f1_score: 0.3576 - loss: 6.4337 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.9289
# Epoch 8/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3655 - custom_f1_score: 0.3242 - loss: 6.1386 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.6855
# Epoch 9/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3744 - custom_f1_score: 0.3540 - loss: 5.8418 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.4626
# Epoch 10/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3834 - custom_f1_score: 0.3480 - loss: 5.6275 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.2582
# Epoch 11/30
# 11/11 - 0s - 13ms/step - accuracy: 0.4071 - custom_f1_score: 0.3792 - loss: 5.3661 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.0732
# Epoch 12/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3848 - custom_f1_score: 0.3605 - loss: 5.2718 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.9047
# Epoch 13/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3819 - custom_f1_score: 0.3594 - loss: 5.0379 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.7438
# Epoch 14/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3700 - custom_f1_score: 0.3522 - loss: 4.8645 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.5945
# Epoch 15/30
# 11/11 - 0s - 11ms/step - accuracy: 0.4071 - custom_f1_score: 0.3767 - loss: 4.7076 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.4603
# Epoch 16/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3462 - custom_f1_score: 0.3270 - loss: 4.5670 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.3278
# Epoch 17/30
# 11/11 - 0s - 30ms/step - accuracy: 0.3967 - custom_f1_score: 0.3778 - loss: 4.4165 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.2071
# Epoch 18/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3863 - custom_f1_score: 0.3651 - loss: 4.2949 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2546 - val_loss: 4.0925
# Epoch 19/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3700 - custom_f1_score: 0.3423 - loss: 4.1763 - val_accuracy: 0.5472 - val_custom_f1_score: 0.2751 - val_loss: 3.9909
# Epoch 20/30
# 11/11 - 0s - 21ms/step - accuracy: 0.3269 - custom_f1_score: 0.3000 - loss: 4.1182 - val_accuracy: 0.6151 - val_custom_f1_score: 0.2869 - val_loss: 3.8829
# Epoch 21/30
# 11/11 - 0s - 18ms/step - accuracy: 0.4056 - custom_f1_score: 0.3881 - loss: 3.9265 - val_accuracy: 0.5334 - val_custom_f1_score: 0.2518 - val_loss: 3.7877
# Epoch 22/30
# 11/11 - 0s - 18ms/step - accuracy: 0.4086 - custom_f1_score: 0.3863 - loss: 3.8261 - val_accuracy: 0.4973 - val_custom_f1_score: 0.2395 - val_loss: 3.6959
# Epoch 23/30
# 11/11 - 0s - 22ms/step - accuracy: 0.3848 - custom_f1_score: 0.3573 - loss: 3.7442 - val_accuracy: 0.4083 - val_custom_f1_score: 0.2093 - val_loss: 3.6093
# Epoch 24/30
# 11/11 - 0s - 18ms/step - accuracy: 0.4116 - custom_f1_score: 0.3887 - loss: 3.6669 - val_accuracy: 0.4295 - val_custom_f1_score: 0.2113 - val_loss: 3.5248
# Epoch 25/30
# 11/11 - 0s - 16ms/step - accuracy: 0.4160 - custom_f1_score: 0.3843 - loss: 3.5667 - val_accuracy: 0.4793 - val_custom_f1_score: 0.2316 - val_loss: 3.4385
# Epoch 26/30
# 11/11 - 0s - 16ms/step - accuracy: 0.4116 - custom_f1_score: 0.3815 - loss: 3.4668 - val_accuracy: 0.4889 - val_custom_f1_score: 0.2411 - val_loss: 3.3576
# Epoch 27/30
# 11/11 - 0s - 14ms/step - accuracy: 0.4324 - custom_f1_score: 0.4061 - loss: 3.3767 - val_accuracy: 0.5133 - val_custom_f1_score: 0.2374 - val_loss: 3.2790
# Epoch 28/30
# 11/11 - 0s - 16ms/step - accuracy: 0.4235 - custom_f1_score: 0.3943 - loss: 3.2963 - val_accuracy: 0.5292 - val_custom_f1_score: 0.2488 - val_loss: 3.2083
# Epoch 29/30
# 11/11 - 0s - 16ms/step - accuracy: 0.4190 - custom_f1_score: 0.4063 - loss: 3.2286 - val_accuracy: 0.4804 - val_custom_f1_score: 0.2333 - val_loss: 3.1486
# Epoch 30/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3893 - custom_f1_score: 0.3538 - loss: 3.2032 - val_accuracy: 0.2418 - val_custom_f1_score: 0.1364 - val_loss: 3.0985
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# Custom accuracy:    Accuracy
# 0      0.24
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_precision...
#
# Epoch 1/30
# 11/11 - 10s - 864ms/step - accuracy: 0.3967 - custom_precision: 0.3578 - loss: 9.4016 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 8.4417
# Epoch 2/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3967 - custom_precision: 0.3741 - loss: 8.7060 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 7.8293
# Epoch 3/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3789 - custom_precision: 0.3515 - loss: 8.1408 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 7.3130
# Epoch 4/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3670 - custom_precision: 0.3354 - loss: 7.6662 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.8794
# Epoch 5/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3462 - custom_precision: 0.3414 - loss: 7.1497 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.5078
# Epoch 6/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3908 - custom_precision: 0.3731 - loss: 6.7524 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.1924
# Epoch 7/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3358 - custom_precision: 0.3104 - loss: 6.5084 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.9163
# Epoch 8/30
# 11/11 - 0s - 11ms/step - accuracy: 0.4042 - custom_precision: 0.3858 - loss: 6.1577 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.6850
# Epoch 9/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3908 - custom_precision: 0.3874 - loss: 5.8673 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.4721
# Epoch 10/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3938 - custom_precision: 0.3774 - loss: 5.6223 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.2718
# Epoch 11/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3492 - custom_precision: 0.3306 - loss: 5.4896 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.0859
# Epoch 12/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3759 - custom_precision: 0.3507 - loss: 5.2789 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.9166
# Epoch 13/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3536 - custom_precision: 0.3470 - loss: 5.0730 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.7560
# Epoch 14/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3863 - custom_precision: 0.3629 - loss: 4.9107 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.6087
# Epoch 15/30
# 11/11 - 0s - 11ms/step - accuracy: 0.4071 - custom_precision: 0.3769 - loss: 4.7718 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.4749
# Epoch 16/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3730 - custom_precision: 0.3567 - loss: 4.6375 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.3510
# Epoch 17/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3863 - custom_precision: 0.3688 - loss: 4.5124 - val_accuracy: 0.5514 - val_custom_precision: 0.2224 - val_loss: 4.2380
# Epoch 18/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3774 - custom_precision: 0.3675 - loss: 4.3342 - val_accuracy: 0.6288 - val_custom_precision: 0.2114 - val_loss: 4.1186
# Epoch 19/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3893 - custom_precision: 0.3708 - loss: 4.2180 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.9891
# Epoch 20/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3834 - custom_precision: 0.3624 - loss: 4.0787 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.8755
# Epoch 21/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3715 - custom_precision: 0.3431 - loss: 3.9888 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.7684
# Epoch 22/30
# 11/11 - 0s - 16ms/step - accuracy: 0.4279 - custom_precision: 0.4033 - loss: 3.8876 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.6715
# Epoch 23/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3536 - custom_precision: 0.3367 - loss: 3.8302 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.5808
# Epoch 24/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3848 - custom_precision: 0.3736 - loss: 3.7193 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.4946
# Epoch 25/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4042 - custom_precision: 0.3873 - loss: 3.6029 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.4068
# Epoch 26/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3848 - custom_precision: 0.3709 - loss: 3.5276 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.3315
# Epoch 27/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3730 - custom_precision: 0.3587 - loss: 3.4748 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.2659
# Epoch 28/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3848 - custom_precision: 0.3690 - loss: 3.4088 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 3.1920
# Epoch 29/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3878 - custom_precision: 0.3667 - loss: 3.3033 - val_accuracy: 0.6299 - val_custom_precision: 0.2191 - val_loss: 3.1249
# Epoch 30/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3878 - custom_precision: 0.3532 - loss: 3.2320 - val_accuracy: 0.6299 - val_custom_precision: 0.2193 - val_loss: 3.0606
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Custom accuracy:    Accuracy
# 0      0.63
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_recall...
#
# Epoch 1/30
# 11/11 - 9s - 827ms/step - accuracy: 0.2987 - custom_recall: 0.3166 - loss: 9.6187 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 8.5526
# Epoch 2/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3403 - custom_recall: 0.3607 - loss: 8.7698 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 7.9739
# Epoch 3/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3061 - custom_recall: 0.3412 - loss: 8.2180 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 7.4791
# Epoch 4/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3744 - custom_recall: 0.4123 - loss: 7.6588 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 7.0584
# Epoch 5/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3432 - custom_recall: 0.3701 - loss: 7.2550 - val_accuracy: 0.6288 - val_custom_recall: 0.3333 - val_loss: 6.6945
# Epoch 6/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3744 - custom_recall: 0.3842 - loss: 6.8416 - val_accuracy: 0.4486 - val_custom_recall: 0.3474 - val_loss: 6.3846
# Epoch 7/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3358 - custom_recall: 0.3476 - loss: 6.4921 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 6.1074
# Epoch 8/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3388 - custom_recall: 0.3501 - loss: 6.2946 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.8598
# Epoch 9/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3611 - custom_recall: 0.3818 - loss: 5.9336 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.6430
# Epoch 10/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3314 - custom_recall: 0.3424 - loss: 5.7879 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.4392
# Epoch 11/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3640 - custom_recall: 0.3708 - loss: 5.4921 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.2481
# Epoch 12/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3522 - custom_recall: 0.3702 - loss: 5.3505 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.0643
# Epoch 13/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3611 - custom_recall: 0.3760 - loss: 5.1688 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.9005
# Epoch 14/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3388 - custom_recall: 0.3628 - loss: 4.9671 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.7547
# Epoch 15/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3551 - custom_recall: 0.3672 - loss: 4.8534 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.6138
# Epoch 16/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3403 - custom_recall: 0.3433 - loss: 4.7178 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.4772
# Epoch 17/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3982 - custom_recall: 0.4287 - loss: 4.5260 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.3588
# Epoch 18/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3789 - custom_recall: 0.3884 - loss: 4.4042 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.2435
# Epoch 19/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3744 - custom_recall: 0.3951 - loss: 4.2866 - val_accuracy: 0.1813 - val_custom_recall: 0.3343 - val_loss: 4.1328
# Epoch 20/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3670 - custom_recall: 0.3760 - loss: 4.1802 - val_accuracy: 0.1676 - val_custom_recall: 0.3242 - val_loss: 4.0281
# Epoch 21/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3685 - custom_recall: 0.3808 - loss: 4.0351 - val_accuracy: 0.1633 - val_custom_recall: 0.3151 - val_loss: 3.9215
# Epoch 22/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3715 - custom_recall: 0.3743 - loss: 3.9030 - val_accuracy: 0.1930 - val_custom_recall: 0.3434 - val_loss: 3.8206
# Epoch 23/30
# 11/11 - 0s - 25ms/step - accuracy: 0.3834 - custom_recall: 0.3854 - loss: 3.8249 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.7320
# Epoch 24/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3715 - custom_recall: 0.3847 - loss: 3.7750 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.6472
# Epoch 25/30
# 11/11 - 0s - 24ms/step - accuracy: 0.3804 - custom_recall: 0.4080 - loss: 3.6478 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.5646
# Epoch 26/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3878 - custom_recall: 0.4122 - loss: 3.6010 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.4781
# Epoch 27/30
# 11/11 - 0s - 26ms/step - accuracy: 0.3893 - custom_recall: 0.3889 - loss: 3.5558 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.4026
# Epoch 28/30
# 11/11 - 0s - 14ms/step - accuracy: 0.4056 - custom_recall: 0.4250 - loss: 3.3953 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.3400
# Epoch 29/30
# 11/11 - 0s - 11ms/step - accuracy: 0.4042 - custom_recall: 0.4109 - loss: 3.3208 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.2806
# Epoch 30/30
# 11/11 - 0s - 11ms/step - accuracy: 0.4116 - custom_recall: 0.4512 - loss: 3.2231 - val_accuracy: 0.1909 - val_custom_recall: 0.3333 - val_loss: 3.2223
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# Custom accuracy:    Accuracy
# 0      0.19
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_f1_score...
#
# Epoch 1/30
# 11/11 - 10s - 922ms/step - accuracy: 0.3403 - custom_f1_score: 0.3098 - loss: 10.0350 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 8.9332
# Epoch 2/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3655 - custom_f1_score: 0.3217 - loss: 9.1668 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 8.2496
# Epoch 3/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3403 - custom_f1_score: 0.3150 - loss: 8.5033 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 7.6700
# Epoch 4/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3566 - custom_f1_score: 0.3416 - loss: 7.8292 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 7.1801
# Epoch 5/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3626 - custom_f1_score: 0.3410 - loss: 7.3877 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 6.7687
# Epoch 6/30
# 11/11 - 0s - 11ms/step - accuracy: 0.4042 - custom_f1_score: 0.3735 - loss: 6.9136 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 6.4130
# Epoch 7/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3640 - custom_f1_score: 0.3286 - loss: 6.6666 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 6.1080
# Epoch 8/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3611 - custom_f1_score: 0.3323 - loss: 6.3228 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.8396
# Epoch 9/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3700 - custom_f1_score: 0.3534 - loss: 6.0044 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.5956
# Epoch 10/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3462 - custom_f1_score: 0.3274 - loss: 5.8289 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.3770
# Epoch 11/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3670 - custom_f1_score: 0.3342 - loss: 5.5700 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 5.1796
# Epoch 12/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3581 - custom_f1_score: 0.3300 - loss: 5.4862 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.9977
# Epoch 13/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3715 - custom_f1_score: 0.3510 - loss: 5.2072 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.8330
# Epoch 14/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3744 - custom_f1_score: 0.3512 - loss: 5.0551 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.6700
# Epoch 15/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3536 - custom_f1_score: 0.3361 - loss: 4.8860 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.5205
# Epoch 16/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3908 - custom_f1_score: 0.3674 - loss: 4.7178 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.3803
# Epoch 17/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3700 - custom_f1_score: 0.3447 - loss: 4.5690 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.2511
# Epoch 18/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3908 - custom_f1_score: 0.3758 - loss: 4.4458 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.1291
# Epoch 19/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3507 - custom_f1_score: 0.3292 - loss: 4.3002 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 4.0110
# Epoch 20/30
# 11/11 - 0s - 13ms/step - accuracy: 0.4086 - custom_f1_score: 0.3801 - loss: 4.1797 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.8986
# Epoch 21/30
# 11/11 - 0s - 17ms/step - accuracy: 0.4131 - custom_f1_score: 0.3853 - loss: 4.0469 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.7920
# Epoch 22/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4205 - custom_f1_score: 0.3928 - loss: 3.9386 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.6905
# Epoch 23/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3923 - custom_f1_score: 0.3661 - loss: 3.8301 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.5965
# Epoch 24/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3774 - custom_f1_score: 0.3523 - loss: 3.7467 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.5151
# Epoch 25/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3789 - custom_f1_score: 0.3506 - loss: 3.6552 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.4373
# Epoch 26/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3952 - custom_f1_score: 0.3694 - loss: 3.5515 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.3644
# Epoch 27/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3923 - custom_f1_score: 0.3731 - loss: 3.4772 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.2905
# Epoch 28/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4606 - custom_f1_score: 0.4379 - loss: 3.3882 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.2173
# Epoch 29/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4056 - custom_f1_score: 0.3810 - loss: 3.3089 - val_accuracy: 0.6288 - val_custom_f1_score: 0.2526 - val_loss: 3.1472
# Epoch 30/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4279 - custom_f1_score: 0.4056 - loss: 3.2458 - val_accuracy: 0.6278 - val_custom_f1_score: 0.2524 - val_loss: 3.0756
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Custom accuracy:    Accuracy
# 0      0.63
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_precision...
#
# Epoch 1/30
# 11/11 - 9s - 809ms/step - accuracy: 0.3314 - custom_precision: 0.3255 - loss: 9.8872 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 8.9144
# Epoch 2/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3254 - custom_precision: 0.3256 - loss: 9.0276 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 8.2364
# Epoch 3/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3180 - custom_precision: 0.3127 - loss: 8.5116 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 7.6719
# Epoch 4/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3551 - custom_precision: 0.3653 - loss: 7.7683 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 7.1981
# Epoch 5/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3789 - custom_precision: 0.3817 - loss: 7.2891 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.7945
# Epoch 6/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3700 - custom_precision: 0.3622 - loss: 6.9371 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.4460
# Epoch 7/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3640 - custom_precision: 0.3739 - loss: 6.6040 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 6.1431
# Epoch 8/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3804 - custom_precision: 0.3664 - loss: 6.3007 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.8777
# Epoch 9/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3596 - custom_precision: 0.3475 - loss: 6.0124 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.6420
# Epoch 10/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3685 - custom_precision: 0.3690 - loss: 5.7506 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.4325
# Epoch 11/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3655 - custom_precision: 0.3492 - loss: 5.5348 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.2372
# Epoch 12/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3744 - custom_precision: 0.3620 - loss: 5.4038 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 5.0581
# Epoch 13/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3536 - custom_precision: 0.3542 - loss: 5.2241 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.8939
# Epoch 14/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3640 - custom_precision: 0.3567 - loss: 5.0334 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.7407
# Epoch 15/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3938 - custom_precision: 0.3904 - loss: 4.8482 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.5878
# Epoch 16/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3759 - custom_precision: 0.3745 - loss: 4.6562 - val_accuracy: 0.6288 - val_custom_precision: 0.2113 - val_loss: 4.4479
# Epoch 17/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3789 - custom_precision: 0.3710 - loss: 4.5661 - val_accuracy: 0.2068 - val_custom_precision: 0.1369 - val_loss: 4.3295
# Epoch 18/30
# 11/11 - 0s - 30ms/step - accuracy: 0.4146 - custom_precision: 0.3991 - loss: 4.3875 - val_accuracy: 0.1888 - val_custom_precision: 0.0844 - val_loss: 4.2138
# Epoch 19/30
# 11/11 - 0s - 20ms/step - accuracy: 0.4131 - custom_precision: 0.4089 - loss: 4.2404 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 4.1008
# Epoch 20/30
# 11/11 - 0s - 22ms/step - accuracy: 0.3700 - custom_precision: 0.3669 - loss: 4.1797 - val_accuracy: 0.1898 - val_custom_precision: 0.0897 - val_loss: 3.9846
# Epoch 21/30
# 11/11 - 0s - 19ms/step - accuracy: 0.3952 - custom_precision: 0.3838 - loss: 3.9947 - val_accuracy: 0.2100 - val_custom_precision: 0.1478 - val_loss: 3.8692
# Epoch 22/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3982 - custom_precision: 0.3963 - loss: 3.9009 - val_accuracy: 0.1951 - val_custom_precision: 0.0938 - val_loss: 3.7714
# Epoch 23/30
# 11/11 - 0s - 29ms/step - accuracy: 0.3640 - custom_precision: 0.3655 - loss: 3.8540 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.6901
# Epoch 24/30
# 11/11 - 0s - 18ms/step - accuracy: 0.4042 - custom_precision: 0.4007 - loss: 3.7365 - val_accuracy: 0.1909 - val_custom_precision: 0.0626 - val_loss: 3.5997
# Epoch 25/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3893 - custom_precision: 0.3819 - loss: 3.6267 - val_accuracy: 0.1898 - val_custom_precision: 0.0624 - val_loss: 3.5097
# Epoch 26/30
# 11/11 - 0s - 17ms/step - accuracy: 0.3848 - custom_precision: 0.3854 - loss: 3.5498 - val_accuracy: 0.1888 - val_custom_precision: 0.0622 - val_loss: 3.4287
# Epoch 27/30
# 11/11 - 0s - 15ms/step - accuracy: 0.4042 - custom_precision: 0.3903 - loss: 3.4176 - val_accuracy: 0.1888 - val_custom_precision: 0.0685 - val_loss: 3.3496
# Epoch 28/30
# 11/11 - 0s - 15ms/step - accuracy: 0.4101 - custom_precision: 0.4097 - loss: 3.3686 - val_accuracy: 0.1888 - val_custom_precision: 0.0903 - val_loss: 3.2682
# Epoch 29/30
# 11/11 - 0s - 15ms/step - accuracy: 0.3997 - custom_precision: 0.3972 - loss: 3.2787 - val_accuracy: 0.1888 - val_custom_precision: 0.0926 - val_loss: 3.1987
# Epoch 30/30
# 11/11 - 0s - 15ms/step - accuracy: 0.4027 - custom_precision: 0.3898 - loss: 3.2008 - val_accuracy: 0.1877 - val_custom_precision: 0.0672 - val_loss: 3.1361
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# Custom accuracy:    Accuracy
# 0      0.19
#
# Training with 30 epochs, learning rate 0.001, and metrics custom_recall...
#
# Epoch 1/30
# 11/11 - 9s - 863ms/step - accuracy: 0.3254 - custom_recall: 0.3280 - loss: 9.9743 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 9.0047
# Epoch 2/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3239 - custom_recall: 0.3274 - loss: 9.2035 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 8.3651
# Epoch 3/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3418 - custom_recall: 0.3399 - loss: 8.4433 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 7.8160
# Epoch 4/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3685 - custom_recall: 0.3681 - loss: 7.8472 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 7.3462
# Epoch 5/30
# 11/11 - 0s - 13ms/step - accuracy: 0.3670 - custom_recall: 0.3725 - loss: 7.3882 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 6.9470
# Epoch 6/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3581 - custom_recall: 0.3749 - loss: 7.0324 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 6.6051
# Epoch 7/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3522 - custom_recall: 0.3600 - loss: 6.6191 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 6.2852
# Epoch 8/30
# 11/11 - 0s - 14ms/step - accuracy: 0.4027 - custom_recall: 0.4168 - loss: 6.2436 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 6.0027
# Epoch 9/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3551 - custom_recall: 0.3617 - loss: 5.9898 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.7578
# Epoch 10/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3744 - custom_recall: 0.3818 - loss: 5.7699 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.5285
# Epoch 11/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3581 - custom_recall: 0.3587 - loss: 5.5219 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.3128
# Epoch 12/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3685 - custom_recall: 0.3669 - loss: 5.3548 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 5.1148
# Epoch 13/30
# 11/11 - 0s - 12ms/step - accuracy: 0.3700 - custom_recall: 0.3632 - loss: 5.1195 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.9183
# Epoch 14/30
# 11/11 - 0s - 11ms/step - accuracy: 0.3700 - custom_recall: 0.3793 - loss: 4.9044 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.7368
# Epoch 15/30
# 11/11 - 0s - 11ms/step - accuracy: 0.4205 - custom_recall: 0.4330 - loss: 4.7092 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.5737
# Epoch 16/30
# 11/11 - 0s - 13ms/step - accuracy: 0.4220 - custom_recall: 0.4250 - loss: 4.5412 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.4196
# Epoch 17/30
# 11/11 - 0s - 12ms/step - accuracy: 0.4027 - custom_recall: 0.4002 - loss: 4.4261 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.2775
# Epoch 18/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3759 - custom_recall: 0.3773 - loss: 4.3347 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.1526
# Epoch 19/30
# 11/11 - 0s - 17ms/step - accuracy: 0.4116 - custom_recall: 0.4167 - loss: 4.1803 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 4.0362
# Epoch 20/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3908 - custom_recall: 0.4003 - loss: 4.0507 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 3.9356
# Epoch 21/30
# 11/11 - 0s - 17ms/step - accuracy: 0.4012 - custom_recall: 0.3873 - loss: 3.9770 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 3.8267
# Epoch 22/30
# 11/11 - 0s - 17ms/step - accuracy: 0.4235 - custom_recall: 0.4144 - loss: 3.8188 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 3.7213
# Epoch 23/30
# 11/11 - 0s - 21ms/step - accuracy: 0.3759 - custom_recall: 0.3566 - loss: 3.7340 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 3.6253
# Epoch 24/30
# 11/11 - 0s - 16ms/step - accuracy: 0.3759 - custom_recall: 0.3798 - loss: 3.6419 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 3.5348
# Epoch 25/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3938 - custom_recall: 0.3932 - loss: 3.5171 - val_accuracy: 0.1803 - val_custom_recall: 0.3333 - val_loss: 3.4428
# Epoch 26/30
# 11/11 - 0s - 18ms/step - accuracy: 0.3923 - custom_recall: 0.4045 - loss: 3.4725 - val_accuracy: 0.1951 - val_custom_recall: 0.3349 - val_loss: 3.3539
# Epoch 27/30
# 11/11 - 0s - 22ms/step - accuracy: 0.4577 - custom_recall: 0.4713 - loss: 3.2940 - val_accuracy: 0.2131 - val_custom_recall: 0.3500 - val_loss: 3.2775
# Epoch 28/30
# 11/11 - 0s - 16ms/step - accuracy: 0.4027 - custom_recall: 0.4294 - loss: 3.2995 - val_accuracy: 0.1824 - val_custom_recall: 0.3428 - val_loss: 3.2065
# Epoch 29/30
# 11/11 - 0s - 13ms/step - accuracy: 0.4116 - custom_recall: 0.4095 - loss: 3.2136 - val_accuracy: 0.1877 - val_custom_recall: 0.3493 - val_loss: 3.1361
# Epoch 30/30
# 11/11 - 0s - 14ms/step - accuracy: 0.3967 - custom_recall: 0.4117 - loss: 3.1217 - val_accuracy: 0.2884 - val_custom_recall: 0.3775 - val_loss: 3.0649
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Custom accuracy:    Accuracy
# 0      0.29

# %%
epochs_list = [30]
models = ['Naive','SV', 'TI', 'Full', 'Hybrid'] 
results_day = {
    'Naive': results_Naive,
    'SV': results_SV,
    'TI': results_TI,
    'Full': results_Full,
    'Hybrid': generate_hybrid_predictions(metric_list,learn_rate_list, epochs_list,  results_SV, results_TI, create_hybrid_predictions)
}

trade_summary_day = create_trade_summary(y_test, results_day, metric_list,learn_rate_list, epochs_list, models)

# %%
trade_summary_day.to_csv('trade_summary_day.csv')
trade_summary_day = pd.read_csv('trade_summary_day.csv',index_col=[0],header=[0,1])
trade_summary_day.columns = pd.MultiIndex.from_tuples([
    ('Naive', 'Accuracy'),  # New name for the first column
    ('Naive', 'Pos_trade_pct'),
    ('Naive', 'Neg_trade_pct'),
    ('Naive', 'Total_transac_pct'),
    ('SV', 'Accuracy'),
    ('SV', 'Pos_trade_pct'),
    ('SV', 'Neg_trade_pct'),
    ('SV', 'Total_transac_pct'),
    ('TI', 'Accuracy'),
    ('TI', 'Pos_trade_pct'),
    ('TI', 'Neg_trade_pct'),
    ('TI', 'Total_transac_pct'),
    ('Full', 'Accuracy'),
    ('Full', 'Pos_trade_pct'),
    ('Full', 'Neg_trade_pct'),
    ('Full', 'Total_transac_pct'),
    ('Hybrid', 'Accuracy'),
    ('Hybrid', 'Pos_trade_pct'),
    ('Hybrid', 'Neg_trade_pct'),
    ('Hybrid', 'Total_transac_pct')
])

# %%
trade_summary_hour = pd.read_csv('trade_summary_hour.csv',index_col=[0],header=[0,1])
trade_summary_hour.columns = pd.MultiIndex.from_tuples([
    ('Naive', 'Accuracy'),  # New name for the first column
    ('Naive', 'Pos_trade_pct'),
    ('Naive', 'Neg_trade_pct'),
    ('Naive', 'Total_transac_pct'),
    ('SV', 'Accuracy'),
    ('SV', 'Pos_trade_pct'),
    ('SV', 'Neg_trade_pct'),
    ('SV', 'Total_transac_pct'),
    ('TI', 'Accuracy'),
    ('TI', 'Pos_trade_pct'),
    ('TI', 'Neg_trade_pct'),
    ('TI', 'Total_transac_pct'),
    ('Full', 'Accuracy'),
    ('Full', 'Pos_trade_pct'),
    ('Full', 'Neg_trade_pct'),
    ('Full', 'Total_transac_pct'),
    ('Hybrid', 'Accuracy'),
    ('Hybrid', 'Pos_trade_pct'),
    ('Hybrid', 'Neg_trade_pct'),
    ('Hybrid', 'Total_transac_pct')
])
# Out:
#                                          Naive                              \
#                                       Accuracy Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)            0.58           56%           44%
# ('custom_precision', 0.001, 30)           0.38          100%            0%
# ('custom_recall', 0.001, 30)              0.63          100%            0%
#
#                                                               SV  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                      11%     0.61
# ('custom_precision', 0.001, 30)                     64%     0.51
# ('custom_recall', 0.001, 30)                         0%     0.60
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                  68%           32%
# ('custom_precision', 0.001, 30)                  0%          100%
# ('custom_recall', 0.001, 30)                     8%           92%
#
#                                                               TI  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                       7%     0.61
# ('custom_precision', 0.001, 30)                     27%     0.63
# ('custom_recall', 0.001, 30)                        12%     0.63
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                  84%           16%
# ('custom_precision', 0.001, 30)                 18%           82%
# ('custom_recall', 0.001, 30)                    18%           82%
#
#                                                             Full  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                      22%     0.62
# ('custom_precision', 0.001, 30)                      9%     0.62
# ('custom_recall', 0.001, 30)                        12%     0.56
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                 100%            0%
# ('custom_precision', 0.001, 30)                 92%            8%
# ('custom_recall', 0.001, 30)                    91%            9%
#
#                                                           Hybrid  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                      17%     0.63
# ('custom_precision', 0.001, 30)                     14%     0.63
# ('custom_recall', 0.001, 30)                        39%     0.63
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                  74%           26%
# ('custom_precision', 0.001, 30)                 27%           73%
# ('custom_recall', 0.001, 30)                    20%           80%
#
#
#                                       Total_transac_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                       2%
# ('custom_precision', 0.001, 30)                      4%
# ('custom_recall', 0.001, 30)                         6%

# %%
trade_summary_hour_naive = trade_summary_hour.loc[:, pd.IndexSlice['Naive', :]]
trade_summary_hour_naive.columns = trade_summary_hour_naive.columns.droplevel(0)
trade_summary_hour_naive.index =  pd.MultiIndex.from_tuples([
    ('Naive', 'custom_f1_score', 0.001, 30),
    ('Naive', 'custom_precision', 0.001, 30),
    ('Naive', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_hour_JP = trade_summary_hour.loc[:, pd.IndexSlice['SV', :]]
trade_summary_hour_JP.columns = trade_summary_hour_JP.columns.droplevel(0)
trade_summary_hour_JP.index =  pd.MultiIndex.from_tuples([
    ('JP', 'custom_f1_score', 0.001, 30),
    ('JP', 'custom_precision', 0.001, 30),
    ('JP', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_hour_TI = trade_summary_hour.loc[:, pd.IndexSlice['TI', :]]
trade_summary_hour_TI.columns = trade_summary_hour_TI.columns.droplevel(0)
trade_summary_hour_TI.index =  pd.MultiIndex.from_tuples([
    ('TI', 'custom_f1_score', 0.001, 30),
    ('TI', 'custom_precision', 0.001, 30),
    ('TI', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_hour_Full = trade_summary_hour.loc[:, pd.IndexSlice['Full', :]]
trade_summary_hour_Full.columns = trade_summary_hour_Full.columns.droplevel(0)
trade_summary_hour_Full.index =  pd.MultiIndex.from_tuples([
    ('Full', 'custom_f1_score', 0.001, 30),
    ('Full', 'custom_precision', 0.001, 30),
    ('Full', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_hour_Hybrid = trade_summary_hour.loc[:, pd.IndexSlice['Hybrid', :]]
trade_summary_hour_Hybrid.columns = trade_summary_hour_Hybrid.columns.droplevel(0)
trade_summary_hour_Hybrid.index =  pd.MultiIndex.from_tuples([
    ('Hybrid', 'custom_f1_score', 0.001, 30),
    ('Hybrid', 'custom_precision', 0.001, 30),
    ('Hybrid', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_hour = pd.concat([trade_summary_hour_naive, trade_summary_hour_TI, trade_summary_hour_JP, trade_summary_hour_Full, trade_summary_hour_Hybrid])
trade_summary_hour

# %%
# Set up the figure with a white background
plt.figure(figsize=(12, 10), facecolor='white')  # Increase the figure size
sns.set_context("notebook", font_scale=1.8)  # Increase font scale for the whole plot
ax = plt.gca()

# Hide the axes
ax.axis('off')

# Define row colors: all rows with no color (white background)
row_colors = ['white'] * len(trade_summary_hour.index)

# Create the table with no color
table = ax.table(
    cellText=trade_summary_hour.values,
    colLabels=trade_summary_hour.columns,
    rowLabels=trade_summary_hour.index,
    cellLoc='center',
    loc='center',
    cellColours=[['white'] * len(trade_summary_hour.columns) for _ in range(len(trade_summary_hour))],  # No color for cells
    colColours=['white'] * len(trade_summary_hour.columns),  # No color for column labels
    rowColours=row_colors  # No color for row labels
)

# Adjust cell height to reduce crowding
for (i, j), cell in table.get_celld().items():
    cell.set_text_props(color='black', fontsize=14)  # Increase font size for cell text
    cell.set_edgecolor('black')  # Set edge color to black
    
    # Adjust cell height for rows
    if i >= 0:  # Exclude column labels row
        cell.set_height(0.05)  # Set height for rows (adjust value as needed)

# Adjust font size for row labels
for i in range(len(trade_summary_hour.index)):
    cell = table[(i + 1, -1)]  # i + 1 because row labels are in the last column
    cell._text.set_fontsize(18)  # Increase font size for row labels

# Adjust font size for column labels
for j in range(len(trade_summary_hour.columns)):
    cell = table[(0, j)]  # Column labels are in the first row
    cell._text.set_fontsize(18)  # Increase font size for column labels

# Save the figure as a PNG
plt.savefig('lstm_trade_summary_hour.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
trade_summary_day
# Out:
#                                          Naive                              \
#                                       Accuracy Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)            0.31          100%            0%
# ('custom_precision', 0.001, 30)           0.19          100%            0%
# ('custom_recall', 0.001, 30)              0.24          100%            0%
#
#                                                               SV  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                      49%     0.18
# ('custom_precision', 0.001, 30)                    100%     0.19
# ('custom_recall', 0.001, 30)                        78%     0.21
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                  72%           28%
# ('custom_precision', 0.001, 30)                 22%           78%
# ('custom_recall', 0.001, 30)                   100%            0%
#
#                                                               TI  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                     100%     0.24
# ('custom_precision', 0.001, 30)                    100%     0.63
# ('custom_recall', 0.001, 30)                        94%     0.19
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                 100%            0%
# ('custom_precision', 0.001, 30)                  0%          100%
# ('custom_recall', 0.001, 30)                   100%            0%
#
#                                                             Full  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                      92%     0.63
# ('custom_precision', 0.001, 30)                      1%     0.19
# ('custom_recall', 0.001, 30)                       100%     0.29
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                 100%            0%
# ('custom_precision', 0.001, 30)                100%            0%
# ('custom_recall', 0.001, 30)                    51%           49%
#
#                                                           Hybrid  \
#                                       Total_transac_pct Accuracy
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                       0%     0.24
# ('custom_precision', 0.001, 30)                     99%     0.63
# ('custom_recall', 0.001, 30)                        89%     0.21
#
#                                                                    \
#                                       Pos_trade_pct Neg_trade_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                 100%            0%
# ('custom_precision', 0.001, 30)                  0%          100%
# ('custom_recall', 0.001, 30)                   100%            0%
#
#
#                                       Total_transac_pct
# ('metric', 'learning_rate', 'epochs')
# ('custom_f1_score', 0.001, 30)                      92%
# ('custom_precision', 0.001, 30)                      1%
# ('custom_recall', 0.001, 30)                        94%

# %%
trade_summary_day_naive = trade_summary_day.loc[:, pd.IndexSlice['Naive', :]]
trade_summary_day_naive.columns = trade_summary_day_naive.columns.droplevel(0)
trade_summary_day_naive.index =  pd.MultiIndex.from_tuples([
    ('Naive', 'custom_f1_score', 0.001, 30),
    ('Naive', 'custom_precision', 0.001, 30),
    ('Naive', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_day_JP = trade_summary_day.loc[:, pd.IndexSlice['SV', :]]
trade_summary_day_JP.columns = trade_summary_day_JP.columns.droplevel(0)
trade_summary_day_JP.index =  pd.MultiIndex.from_tuples([
    ('JP', 'custom_f1_score', 0.001, 30),
    ('JP', 'custom_precision', 0.001, 30),
    ('JP', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_day_TI = trade_summary_day.loc[:, pd.IndexSlice['TI', :]]
trade_summary_day_TI.columns = trade_summary_day_TI.columns.droplevel(0)
trade_summary_day_TI.index =  pd.MultiIndex.from_tuples([
    ('TI', 'custom_f1_score', 0.001, 30),
    ('TI', 'custom_precision', 0.001, 30),
    ('TI', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_day_Full = trade_summary_day.loc[:, pd.IndexSlice['Full', :]]
trade_summary_day_Full.columns = trade_summary_day_Full.columns.droplevel(0)
trade_summary_day_Full.index =  pd.MultiIndex.from_tuples([
    ('Full', 'custom_f1_score', 0.001, 30),
    ('Full', 'custom_precision', 0.001, 30),
    ('Full', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_day_Hybrid = trade_summary_day.loc[:, pd.IndexSlice['Hybrid', :]]
trade_summary_day_Hybrid.columns = trade_summary_day_Hybrid.columns.droplevel(0)
trade_summary_day_Hybrid.index =  pd.MultiIndex.from_tuples([
    ('Hybrid', 'custom_f1_score', 0.001, 30),
    ('Hybrid', 'custom_precision', 0.001, 30),
    ('Hybrid', 'custom_recall', 0.001, 30)
], names=['model', 'metric', 'learning_rate', 'epochs'])

trade_summary_day = pd.concat([trade_summary_day_naive, trade_summary_day_TI, trade_summary_day_JP, trade_summary_day_Full, trade_summary_day_Hybrid])
trade_summary_day
# Out:
#                                               Accuracy Pos_trade_pct  \
# model  metric           learning_rate epochs
# Naive  custom_f1_score  0.001         30          0.31          100%
#        custom_precision 0.001         30          0.19          100%
#        custom_recall    0.001         30          0.24          100%
# TI     custom_f1_score  0.001         30          0.24          100%
#        custom_precision 0.001         30          0.63            0%
#        custom_recall    0.001         30          0.19          100%
# JP     custom_f1_score  0.001         30          0.18           72%
#        custom_precision 0.001         30          0.19           22%
#        custom_recall    0.001         30          0.21          100%
# Full   custom_f1_score  0.001         30          0.63          100%
#        custom_precision 0.001         30          0.19          100%
#        custom_recall    0.001         30          0.29           51%
# Hybrid custom_f1_score  0.001         30          0.24          100%
#        custom_precision 0.001         30          0.63            0%
#        custom_recall    0.001         30          0.21          100%
#
#                                              Neg_trade_pct Total_transac_pct
# model  metric           learning_rate epochs
# Naive  custom_f1_score  0.001         30                0%               49%
#        custom_precision 0.001         30                0%              100%
#        custom_recall    0.001         30                0%               78%
# TI     custom_f1_score  0.001         30                0%               92%
#        custom_precision 0.001         30              100%                1%
#        custom_recall    0.001         30                0%              100%
# JP     custom_f1_score  0.001         30               28%              100%
#        custom_precision 0.001         30               78%              100%
#        custom_recall    0.001         30                0%               94%
# Full   custom_f1_score  0.001         30                0%                0%
#        custom_precision 0.001         30                0%               99%
#        custom_recall    0.001         30               49%               89%
# Hybrid custom_f1_score  0.001         30                0%               92%
#        custom_precision 0.001         30              100%                1%
#        custom_recall    0.001         30                0%               94%

# %%
# Set up the figure with a white background
plt.figure(figsize=(12, 10), facecolor='white')  # Increase the figure size
sns.set_context("notebook", font_scale=1.8)  # Increase font scale for the whole plot
ax = plt.gca()

# Hide the axes
ax.axis('off')

# Define row colors: all rows with no color (white background)
row_colors = ['white'] * len(trade_summary_day.index)

# Create the table with no color
table = ax.table(
    cellText=trade_summary_day.values,
    colLabels=trade_summary_day.columns,
    rowLabels=trade_summary_day.index,
    cellLoc='center',
    loc='center',
    cellColours=[['white'] * len(trade_summary_day.columns) for _ in range(len(trade_summary_day))],  # No color for cells
    colColours=['white'] * len(trade_summary_day.columns),  # No color for column labels
    rowColours=row_colors  # No color for row labels
)

# Adjust cell height to reduce crowding
for (i, j), cell in table.get_celld().items():
    cell.set_text_props(color='black', fontsize=14)  # Increase font size for cell text
    cell.set_edgecolor('black')  # Set edge color to black
    
    # Adjust cell height for rows
    if i >= 0:  # Exclude column labels row
        cell.set_height(0.05)  # Set height for rows (adjust value as needed)

# Adjust font size for row labels
for i in range(len(trade_summary_day.index)):
    cell = table[(i + 1, -1)]  # i + 1 because row labels are in the last column
    cell._text.set_fontsize(18)  # Increase font size for row labels

# Adjust font size for column labels
for j in range(len(trade_summary_day.columns)):
    cell = table[(0, j)]  # Column labels are in the first row
    cell._text.set_fontsize(18)  # Increase font size for column labels

# Save the figure as a PNG
plt.savefig('lstm_trade_summary_day.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# # end
